# %%
# !unzip drive/MyDrive/AIJ_2GIS_ru.zip
# !unzip AIJ_2GIS_ru/AIJ_2gis.zip

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import torch.nn as nn
import torch

from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from torchvision import transforms
from torchvision import models
from tqdm.notebook import tqdm

import random
from PIL import Image

import math

# %%
device = torch.device("cuda")
random.seed(1)

# %%
def get_classes():
    classes = []

    file_ = open("AIJ_2gis/train.csv", "r")
    for line in file_.readlines()[1:]:
        _, label = line.split(",")
        label = label.split("+")[0].rstrip("\n")

        if label not in classes:
            classes.append(label)
    
    return sorted(classes)

# %%
class Data(Dataset):
    def __init__(self, i, j, seed, transform, device):
        super(Data, self).__init__()
        self.transform = transform
        self.device = device

        self.classes = get_classes()
        self.length = len(self.classes)

        file_ = open("AIJ_2gis/train.csv", "r")
        table = file_.readlines()[1:]

        random.seed(seed)
        random.shuffle(table)

        self.table = [line.split(",") for line in table[i:j]]
    
    def __len__(self):
        return len(self.table)
    
    def __getitem__(self, index):
        file_name, label = self.table[index]
        label = label.split("+")[0].rstrip("\n")
        
        img = Image.open("AIJ_2gis/" + file_name)
        img = self.transform(img).to(self.device)

        return img, self.get_tensor(label)

    def get_tensor(self, label):
        tensor = torch.zeros(self.length)
        tensor[self.classes.index(label)] = 1
        return tensor.to(self.device)

# %%
train_data = Data(
    i=1, j=45000, seed=45, device=device,
    transform=transforms.Compose([
        transforms.Resize([55, 55]),
        transforms.RandomRotation((-5, 5)),
        
        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
    ])
)

test_data = Data(
    i=45000, j=45700, seed=45, device=device,
    transform=transforms.Compose([
        transforms.Resize([55, 55]),

        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
    ])
)

val_data = Data(
    i=45700, j=46060, seed=45, device=device,
    transform=transforms.Compose([
        transforms.Resize([55, 55]),

        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
    ])
)

# %%
train_dataloader = DataLoader(train_data, batch_size=50, shuffle=True)

# %%
len(train_data.classes)
# Out:
# 153

# %%
def plot_history(train_history, val_history, title='loss'):
    plt.figure()
    plt.title('{}'.format(title))
    plt.plot(train_history, label='train', zorder=1)
    
    points = np.array(val_history)
    steps = list(range(0, len(train_history) + 1, int(len(train_history) / len(val_history))))[1:]
    
    plt.scatter(steps, val_history, marker='+', s=180, c='orange', label='val', zorder=2)
    plt.xlabel('train steps')
    
    plt.legend(loc='best')
    plt.grid()

    plt.show()

# %%
class Net(nn.Module):
    def __init__(self, in_channels, n_classes):
        super(Net, self).__init__()
        self.model = models.densenet121(pretrained=False)
        self.model.features.conv0 = nn.Conv2d(in_channels, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
        self.model.classifier = nn.Linear(in_features=1024, out_features=n_classes, bias=True)
    
    def forward(self, x):
        x = self.model(x)
        return x

# %%
def numel(m: torch.nn.Module, only_trainable: bool = False):
    """
    returns the total number of parameters used by `m` (only counting
    shared parameters once); if `only_trainable` is True, then only
    includes parameters with `requires_grad = True`
    """
    parameters = m.parameters()
    if only_trainable:
        parameters = list(p for p in parameters if p.requires_grad)
    unique = dict((p.data_ptr(), p) for p in parameters).values()
    return sum(p.numel() for p in unique)

# %%
model = Net(in_channels=1, n_classes=train_data.length)
model.to(device)

# %%
print(numel(model, False))
# Out:
# 7104409

# %%
def checkpoint(accuracy):
    PATH = f"./drive/MyDrive/AIJ_2gis/checkpoints/checkpoint_accuracy-{accuracy}.pth"
    torch.save(model.state_dict(), PATH)
    print("checkpoint created - " + PATH)

# %%
def train(model, criterion, optimizer, train_dataloader, scheduler1, scheduler2, NUM_EPOCH=20):
    running_loss = .0
    train_size = .0
    
    loss_log = []
    accuracy_log = []

    correct = 0
    count = 0

    model.train()

    for epoch in range(NUM_EPOCH):
        tq = tqdm(enumerate(train_dataloader), total=math.ceil(len(train_data) / train_dataloader.batch_size), ascii=True)
        tq.set_description("Epoch #" + str(epoch + 1))

        for i, (x, y) in tq:
            optimizer.zero_grad()
            out = nn.LogSoftmax(model(x)).dim

            loss = criterion(out, y.argmax(dim=1))
            loss.backward()

            running_loss = loss.item()
            train_size += out.size(0)

            optimizer.step()

            for i in range(int(out.shape[0])):
                if list(out[i]).index(max(out[i])) == list(y[i]).index(max(y[i])):
                    correct += 1
            
            count += int(out.shape[0])

            loss_log.append(loss.data / out.size(0))
            accuracy_log.append(correct / count)


            tq.set_postfix({
                "loss": (running_loss / train_size) * 1000,
                "accuracy": correct / count,
            })
        
        scheduler1.step()
        scheduler2.step()
        
        val_accuracy = evaluate(model, val_data)
        print("Val accuracy: %.3f" % (val_accuracy,) )
        checkpoint(val_accuracy)

    
    return loss_log, accuracy_log

# %%
def evaluate(model, data):
    model.eval()
    
    correct = 0
    for x, y in data:
        out = nn.LogSoftmax(model(x.view(1, 1, 55, 55))).dim[0]
        if list(out).index(max(out)) == list(y).index(max(y)):
            correct += 1
    return correct / len(data)

# %%
model.load_state_dict(torch.load("./drive/MyDrive/AIJ_2gis/checkpoints/checkpoint_accuracy-0.9944444444444445.pth"))
# Out:
# <All keys matched successfully>

# %%
evaluate(model, val_data)
# Out:
# 0.9944444444444445

# %%
optimizer = torch.optim.Adamax(model.parameters(), lr=0.01)
scheduler1 = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
scheduler2 = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[30,80], gamma=0.1)

criterion = nn.CrossEntropyLoss()

# %%
log = train(model, criterion, optimizer, train_dataloader, scheduler1, scheduler2, 1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=900.0), HTML(value='')))
# Val accuracy: 0.989
# checkpoint created - ./drive/MyDrive/AIJ_2gis/checkpoints/checkpoint_accuracy-0.9888888888888889.pth

# %%
torch.onnx.export(model, torch.randn(1, 1, 55, 55, device='cuda'), "./drive/MyDrive/AIJ_2gis/model.onnx", verbose=True, input_names=["actual_input_1"]+ [ "learned_%d" % i for i in range(16) ], opset_version=10, output_names=["otput1"])
# Out:
# graph(%actual_input_1 : Float(1, 1, 55, 55, strides=[3025, 3025, 55, 1], requires_grad=0, device=cuda:0),
#       %learned_6 : Float(64, strides=[1], requires_grad=1, device=cuda:0),
#       %learned_7 : Float(64, strides=[1], requires_grad=1, device=cuda:0),
#       %learned_8 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %learned_9 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer1.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer2.norm1.weight : Float(96, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer2.norm1.bias : Float(96, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer2.norm1.running_mean : Float(96, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer2.norm1.running_var : Float(96, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer2.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer3.norm1.weight : Float(128, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer3.norm1.bias : Float(128, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer3.norm1.running_mean : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer3.norm1.running_var : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer3.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer4.norm1.weight : Float(160, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer4.norm1.bias : Float(160, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer4.norm1.running_mean : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer4.norm1.running_var : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer4.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer5.norm1.weight : Float(192, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer5.norm1.bias : Float(192, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer5.norm1.running_mean : Float(192, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer5.norm1.running_var : Float(192, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer5.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer6.norm1.weight : Float(224, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer6.norm1.bias : Float(224, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock1.denselayer6.norm1.running_mean : Float(224, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer6.norm1.running_var : Float(224, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock1.denselayer6.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.transition1.norm.weight : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.transition1.norm.bias : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.transition1.norm.running_mean : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.transition1.norm.running_var : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.transition1.conv.weight : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer1.norm1.weight : Float(128, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer1.norm1.bias : Float(128, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer1.norm1.running_mean : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer1.norm1.running_var : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer1.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer2.norm1.weight : Float(160, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer2.norm1.bias : Float(160, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer2.norm1.running_mean : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer2.norm1.running_var : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer2.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer3.norm1.weight : Float(192, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer3.norm1.bias : Float(192, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer3.norm1.running_mean : Float(192, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer3.norm1.running_var : Float(192, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer3.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer4.norm1.weight : Float(224, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer4.norm1.bias : Float(224, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer4.norm1.running_mean : Float(224, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer4.norm1.running_var : Float(224, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer4.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer5.norm1.weight : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer5.norm1.bias : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer5.norm1.running_mean : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer5.norm1.running_var : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer5.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer6.norm1.weight : Float(288, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer6.norm1.bias : Float(288, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer6.norm1.running_mean : Float(288, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer6.norm1.running_var : Float(288, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer6.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer7.norm1.weight : Float(320, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer7.norm1.bias : Float(320, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer7.norm1.running_mean : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer7.norm1.running_var : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer7.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer8.norm1.weight : Float(352, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer8.norm1.bias : Float(352, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer8.norm1.running_mean : Float(352, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer8.norm1.running_var : Float(352, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer8.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer9.norm1.weight : Float(384, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer9.norm1.bias : Float(384, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer9.norm1.running_mean : Float(384, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer9.norm1.running_var : Float(384, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer9.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer10.norm1.weight : Float(416, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer10.norm1.bias : Float(416, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer10.norm1.running_mean : Float(416, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer10.norm1.running_var : Float(416, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer10.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer11.norm1.weight : Float(448, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer11.norm1.bias : Float(448, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer11.norm1.running_mean : Float(448, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer11.norm1.running_var : Float(448, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer11.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer12.norm1.weight : Float(480, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer12.norm1.bias : Float(480, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock2.denselayer12.norm1.running_mean : Float(480, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer12.norm1.running_var : Float(480, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock2.denselayer12.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.transition2.norm.weight : Float(512, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.transition2.norm.bias : Float(512, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.transition2.norm.running_mean : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.transition2.norm.running_var : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.transition2.conv.weight : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer1.norm1.weight : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer1.norm1.bias : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer1.norm1.running_mean : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer1.norm1.running_var : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer1.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer2.norm1.weight : Float(288, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer2.norm1.bias : Float(288, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer2.norm1.running_mean : Float(288, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer2.norm1.running_var : Float(288, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer2.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer3.norm1.weight : Float(320, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer3.norm1.bias : Float(320, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer3.norm1.running_mean : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer3.norm1.running_var : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer3.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer4.norm1.weight : Float(352, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer4.norm1.bias : Float(352, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer4.norm1.running_mean : Float(352, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer4.norm1.running_var : Float(352, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer4.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer5.norm1.weight : Float(384, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer5.norm1.bias : Float(384, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer5.norm1.running_mean : Float(384, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer5.norm1.running_var : Float(384, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer5.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer6.norm1.weight : Float(416, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer6.norm1.bias : Float(416, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer6.norm1.running_mean : Float(416, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer6.norm1.running_var : Float(416, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer6.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer7.norm1.weight : Float(448, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer7.norm1.bias : Float(448, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer7.norm1.running_mean : Float(448, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer7.norm1.running_var : Float(448, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer7.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer8.norm1.weight : Float(480, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer8.norm1.bias : Float(480, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer8.norm1.running_mean : Float(480, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer8.norm1.running_var : Float(480, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer8.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer9.norm1.weight : Float(512, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer9.norm1.bias : Float(512, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer9.norm1.running_mean : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer9.norm1.running_var : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer9.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer10.norm1.weight : Float(544, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer10.norm1.bias : Float(544, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer10.norm1.running_mean : Float(544, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer10.norm1.running_var : Float(544, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer10.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer11.norm1.weight : Float(576, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer11.norm1.bias : Float(576, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer11.norm1.running_mean : Float(576, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer11.norm1.running_var : Float(576, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer11.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer12.norm1.weight : Float(608, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer12.norm1.bias : Float(608, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer12.norm1.running_mean : Float(608, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer12.norm1.running_var : Float(608, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer12.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer13.norm1.weight : Float(640, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer13.norm1.bias : Float(640, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer13.norm1.running_mean : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer13.norm1.running_var : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer13.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer14.norm1.weight : Float(672, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer14.norm1.bias : Float(672, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer14.norm1.running_mean : Float(672, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer14.norm1.running_var : Float(672, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer14.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer15.norm1.weight : Float(704, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer15.norm1.bias : Float(704, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer15.norm1.running_mean : Float(704, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer15.norm1.running_var : Float(704, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer15.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer16.norm1.weight : Float(736, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer16.norm1.bias : Float(736, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer16.norm1.running_mean : Float(736, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer16.norm1.running_var : Float(736, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer16.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer17.norm1.weight : Float(768, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer17.norm1.bias : Float(768, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer17.norm1.running_mean : Float(768, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer17.norm1.running_var : Float(768, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer17.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer18.norm1.weight : Float(800, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer18.norm1.bias : Float(800, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer18.norm1.running_mean : Float(800, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer18.norm1.running_var : Float(800, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer18.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer19.norm1.weight : Float(832, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer19.norm1.bias : Float(832, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer19.norm1.running_mean : Float(832, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer19.norm1.running_var : Float(832, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer19.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer20.norm1.weight : Float(864, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer20.norm1.bias : Float(864, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer20.norm1.running_mean : Float(864, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer20.norm1.running_var : Float(864, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer20.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer21.norm1.weight : Float(896, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer21.norm1.bias : Float(896, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer21.norm1.running_mean : Float(896, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer21.norm1.running_var : Float(896, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer21.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer22.norm1.weight : Float(928, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer22.norm1.bias : Float(928, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer22.norm1.running_mean : Float(928, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer22.norm1.running_var : Float(928, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer22.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer23.norm1.weight : Float(960, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer23.norm1.bias : Float(960, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer23.norm1.running_mean : Float(960, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer23.norm1.running_var : Float(960, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer23.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer24.norm1.weight : Float(992, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer24.norm1.bias : Float(992, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock3.denselayer24.norm1.running_mean : Float(992, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer24.norm1.running_var : Float(992, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock3.denselayer24.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.transition3.norm.weight : Float(1024, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.transition3.norm.bias : Float(1024, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.transition3.norm.running_mean : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.transition3.norm.running_var : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.transition3.conv.weight : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer1.norm1.weight : Float(512, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer1.norm1.bias : Float(512, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer1.norm1.running_mean : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer1.norm1.running_var : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer1.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer2.norm1.weight : Float(544, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer2.norm1.bias : Float(544, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer2.norm1.running_mean : Float(544, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer2.norm1.running_var : Float(544, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer2.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer3.norm1.weight : Float(576, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer3.norm1.bias : Float(576, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer3.norm1.running_mean : Float(576, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer3.norm1.running_var : Float(576, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer3.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer4.norm1.weight : Float(608, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer4.norm1.bias : Float(608, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer4.norm1.running_mean : Float(608, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer4.norm1.running_var : Float(608, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer4.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer5.norm1.weight : Float(640, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer5.norm1.bias : Float(640, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer5.norm1.running_mean : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer5.norm1.running_var : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer5.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer6.norm1.weight : Float(672, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer6.norm1.bias : Float(672, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer6.norm1.running_mean : Float(672, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer6.norm1.running_var : Float(672, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer6.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer7.norm1.weight : Float(704, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer7.norm1.bias : Float(704, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer7.norm1.running_mean : Float(704, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer7.norm1.running_var : Float(704, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer7.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer8.norm1.weight : Float(736, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer8.norm1.bias : Float(736, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer8.norm1.running_mean : Float(736, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer8.norm1.running_var : Float(736, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer8.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer9.norm1.weight : Float(768, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer9.norm1.bias : Float(768, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer9.norm1.running_mean : Float(768, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer9.norm1.running_var : Float(768, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer9.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer10.norm1.weight : Float(800, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer10.norm1.bias : Float(800, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer10.norm1.running_mean : Float(800, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer10.norm1.running_var : Float(800, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer10.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer11.norm1.weight : Float(832, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer11.norm1.bias : Float(832, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer11.norm1.running_mean : Float(832, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer11.norm1.running_var : Float(832, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer11.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer12.norm1.weight : Float(864, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer12.norm1.bias : Float(864, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer12.norm1.running_mean : Float(864, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer12.norm1.running_var : Float(864, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer12.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer13.norm1.weight : Float(896, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer13.norm1.bias : Float(896, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer13.norm1.running_mean : Float(896, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer13.norm1.running_var : Float(896, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer13.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer14.norm1.weight : Float(928, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer14.norm1.bias : Float(928, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer14.norm1.running_mean : Float(928, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer14.norm1.running_var : Float(928, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer14.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer15.norm1.weight : Float(960, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer15.norm1.bias : Float(960, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer15.norm1.running_mean : Float(960, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer15.norm1.running_var : Float(960, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer15.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer16.norm1.weight : Float(992, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer16.norm1.bias : Float(992, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.denseblock4.denselayer16.norm1.running_mean : Float(992, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer16.norm1.running_var : Float(992, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.denseblock4.denselayer16.conv2.weight : Float(32, 128, 3, 3, strides=[1152, 9, 3, 1], requires_grad=1, device=cuda:0),
#       %model.features.norm5.weight : Float(1024, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.norm5.bias : Float(1024, strides=[1], requires_grad=1, device=cuda:0),
#       %model.features.norm5.running_mean : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %model.features.norm5.running_var : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %model.classifier.weight : Float(153, 1024, strides=[1024, 1], requires_grad=1, device=cuda:0),
#       %model.classifier.bias : Float(153, strides=[1], requires_grad=1, device=cuda:0),
#       %1163 : Float(64, 1, 7, 7, strides=[49, 49, 7, 1], requires_grad=0, device=cuda:0),
#       %1164 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %1166 : Float(128, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1167 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1169 : Float(128, 96, 1, 1, strides=[96, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1170 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1172 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1173 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1175 : Float(128, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1176 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1178 : Float(128, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1179 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1181 : Float(128, 224, 1, 1, strides=[224, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1182 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1184 : Float(128, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1185 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1187 : Float(128, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1188 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1190 : Float(128, 192, 1, 1, strides=[192, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1191 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1193 : Float(128, 224, 1, 1, strides=[224, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1194 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1196 : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1197 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1199 : Float(128, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1200 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1202 : Float(128, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1203 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1205 : Float(128, 352, 1, 1, strides=[352, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1206 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1208 : Float(128, 384, 1, 1, strides=[384, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1209 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1211 : Float(128, 416, 1, 1, strides=[416, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1212 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1214 : Float(128, 448, 1, 1, strides=[448, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1215 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1217 : Float(128, 480, 1, 1, strides=[480, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1218 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1220 : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1221 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1223 : Float(128, 288, 1, 1, strides=[288, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1224 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1226 : Float(128, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1227 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1229 : Float(128, 352, 1, 1, strides=[352, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1230 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1232 : Float(128, 384, 1, 1, strides=[384, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1233 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1235 : Float(128, 416, 1, 1, strides=[416, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1236 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1238 : Float(128, 448, 1, 1, strides=[448, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1239 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1241 : Float(128, 480, 1, 1, strides=[480, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1242 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1244 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1245 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1247 : Float(128, 544, 1, 1, strides=[544, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1248 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1250 : Float(128, 576, 1, 1, strides=[576, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1251 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1253 : Float(128, 608, 1, 1, strides=[608, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1254 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1256 : Float(128, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1257 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1259 : Float(128, 672, 1, 1, strides=[672, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1260 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1262 : Float(128, 704, 1, 1, strides=[704, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1263 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1265 : Float(128, 736, 1, 1, strides=[736, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1266 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1268 : Float(128, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1269 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1271 : Float(128, 800, 1, 1, strides=[800, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1272 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1274 : Float(128, 832, 1, 1, strides=[832, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1275 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1277 : Float(128, 864, 1, 1, strides=[864, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1278 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1280 : Float(128, 896, 1, 1, strides=[896, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1281 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1283 : Float(128, 928, 1, 1, strides=[928, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1284 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1286 : Float(128, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1287 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1289 : Float(128, 992, 1, 1, strides=[992, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1290 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1292 : Float(128, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1293 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1295 : Float(128, 544, 1, 1, strides=[544, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1296 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1298 : Float(128, 576, 1, 1, strides=[576, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1299 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1301 : Float(128, 608, 1, 1, strides=[608, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1302 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1304 : Float(128, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1305 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1307 : Float(128, 672, 1, 1, strides=[672, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1308 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1310 : Float(128, 704, 1, 1, strides=[704, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1311 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1313 : Float(128, 736, 1, 1, strides=[736, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1314 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1316 : Float(128, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1317 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1319 : Float(128, 800, 1, 1, strides=[800, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1320 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1322 : Float(128, 832, 1, 1, strides=[832, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1323 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1325 : Float(128, 864, 1, 1, strides=[864, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1326 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1328 : Float(128, 896, 1, 1, strides=[896, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1329 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1331 : Float(128, 928, 1, 1, strides=[928, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1332 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1334 : Float(128, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1335 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %1337 : Float(128, 992, 1, 1, strides=[992, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1338 : Float(128, strides=[1], requires_grad=0, device=cuda:0)):
# ...
#   %1094 : Float(1, 736, 1, 1, strides=[736, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1093, %model.features.denseblock4.denselayer8.norm1.weight, %model.features.denseblock4.denselayer8.norm1.bias, %model.features.denseblock4.denselayer8.norm1.running_mean, %model.features.denseblock4.denselayer8.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1095 : Float(1, 736, 1, 1, strides=[736, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1094) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1312 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1095, %1313, %1314)
#   %1098 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1312) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1099 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1098, %model.features.denseblock4.denselayer8.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1100 : Float(1, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1101 : Float(1, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1100, %model.features.denseblock4.denselayer9.norm1.weight, %model.features.denseblock4.denselayer9.norm1.bias, %model.features.denseblock4.denselayer9.norm1.running_mean, %model.features.denseblock4.denselayer9.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1102 : Float(1, 768, 1, 1, strides=[768, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1101) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1315 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1102, %1316, %1317)
#   %1105 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1315) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1106 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1105, %model.features.denseblock4.denselayer9.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1107 : Float(1, 800, 1, 1, strides=[800, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1108 : Float(1, 800, 1, 1, strides=[800, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1107, %model.features.denseblock4.denselayer10.norm1.weight, %model.features.denseblock4.denselayer10.norm1.bias, %model.features.denseblock4.denselayer10.norm1.running_mean, %model.features.denseblock4.denselayer10.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1109 : Float(1, 800, 1, 1, strides=[800, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1108) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1318 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1109, %1319, %1320)
#   %1112 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1318) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1113 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1112, %model.features.denseblock4.denselayer10.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1114 : Float(1, 832, 1, 1, strides=[832, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106, %1113) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1115 : Float(1, 832, 1, 1, strides=[832, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1114, %model.features.denseblock4.denselayer11.norm1.weight, %model.features.denseblock4.denselayer11.norm1.bias, %model.features.denseblock4.denselayer11.norm1.running_mean, %model.features.denseblock4.denselayer11.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1116 : Float(1, 832, 1, 1, strides=[832, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1115) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1321 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1116, %1322, %1323)
#   %1119 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1321) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1120 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1119, %model.features.denseblock4.denselayer11.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1121 : Float(1, 864, 1, 1, strides=[864, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106, %1113, %1120) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1122 : Float(1, 864, 1, 1, strides=[864, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1121, %model.features.denseblock4.denselayer12.norm1.weight, %model.features.denseblock4.denselayer12.norm1.bias, %model.features.denseblock4.denselayer12.norm1.running_mean, %model.features.denseblock4.denselayer12.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1123 : Float(1, 864, 1, 1, strides=[864, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1122) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1324 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1123, %1325, %1326)
#   %1126 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1324) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1127 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1126, %model.features.denseblock4.denselayer12.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1128 : Float(1, 896, 1, 1, strides=[896, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106, %1113, %1120, %1127) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1129 : Float(1, 896, 1, 1, strides=[896, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1128, %model.features.denseblock4.denselayer13.norm1.weight, %model.features.denseblock4.denselayer13.norm1.bias, %model.features.denseblock4.denselayer13.norm1.running_mean, %model.features.denseblock4.denselayer13.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1130 : Float(1, 896, 1, 1, strides=[896, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1129) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1327 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1130, %1328, %1329)
#   %1133 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1327) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1134 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1133, %model.features.denseblock4.denselayer13.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1135 : Float(1, 928, 1, 1, strides=[928, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106, %1113, %1120, %1127, %1134) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1136 : Float(1, 928, 1, 1, strides=[928, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1135, %model.features.denseblock4.denselayer14.norm1.weight, %model.features.denseblock4.denselayer14.norm1.bias, %model.features.denseblock4.denselayer14.norm1.running_mean, %model.features.denseblock4.denselayer14.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1137 : Float(1, 928, 1, 1, strides=[928, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1136) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1330 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1137, %1331, %1332)
#   %1140 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1330) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1141 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1140, %model.features.denseblock4.denselayer14.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1142 : Float(1, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106, %1113, %1120, %1127, %1134, %1141) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1143 : Float(1, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1142, %model.features.denseblock4.denselayer15.norm1.weight, %model.features.denseblock4.denselayer15.norm1.bias, %model.features.denseblock4.denselayer15.norm1.running_mean, %model.features.denseblock4.denselayer15.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1144 : Float(1, 960, 1, 1, strides=[960, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1143) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1333 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1144, %1334, %1335)
#   %1147 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1333) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1148 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1147, %model.features.denseblock4.denselayer15.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1149 : Float(1, 992, 1, 1, strides=[992, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106, %1113, %1120, %1127, %1134, %1141, %1148) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:52:0
#   %1150 : Float(1, 992, 1, 1, strides=[992, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1149, %model.features.denseblock4.denselayer16.norm1.weight, %model.features.denseblock4.denselayer16.norm1.bias, %model.features.denseblock4.denselayer16.norm1.running_mean, %model.features.denseblock4.denselayer16.norm1.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1151 : Float(1, 992, 1, 1, strides=[992, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1150) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1336 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1151, %1337, %1338)
#   %1154 : Float(1, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1336) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1155 : Float(1, 32, 1, 1, strides=[32, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1154, %model.features.denseblock4.denselayer16.conv2.weight) # /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py:440:0
#   %1156 : Float(1, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%1043, %1050, %1057, %1064, %1071, %1078, %1085, %1092, %1099, %1106, %1113, %1120, %1127, %1134, %1141, %1148, %1155) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:129:0
#   %1157 : Float(1, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::BatchNormalization[epsilon=1.0000000000000001e-05, momentum=0.90000000000000002](%1156, %model.features.norm5.weight, %model.features.norm5.bias, %model.features.norm5.running_mean, %model.features.norm5.running_var) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:2282:0
#   %1158 : Float(1, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%1157) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1296:0
#   %1159 : Float(1, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::GlobalAveragePool(%1158) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1130:0
#   %1160 : Float(1, 1024, strides=[1024, 1], requires_grad=1, device=cuda:0) = onnx::Flatten[axis=1](%1159) # /usr/local/lib/python3.7/dist-packages/torchvision/models/densenet.py:219:0
#   %otput1 : Float(1, 153, strides=[153, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1](%1160, %model.classifier.weight, %model.classifier.bias) # /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1847:0
#   return (%otput1)

# %%
out = nn.LogSoftmax(model(train_data[0][0].view(1, 1, 55, 55))).dim[0]
list(out).index(max(out)), list(train_data[0][1]).index(max(train_data[0][1]))
